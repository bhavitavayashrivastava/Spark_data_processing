# %%
import findspark
findspark.init()
#from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

sc = SparkContext("local[*]","LocalWordCount")
ssc = StreamingContext(sc,1)

# %%
#spark.stop()

# %%
lines = ssc.socketTextStream("localhost",9999)

# %%
words = lines.flatMap(lambda x: x.split(" "))

# %%
from pprint import pprint
pair = words.map(lambda x: (x,1))
wordCount = pair.reduceByKey(lambda x,y: x+y)
wordCount.pprint()

# %%
ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2020-12-25 12:30:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:37
# -------------------------------------------
# ('hello', 1)
# ('world', 1)
#
# -------------------------------------------
# Time: 2020-12-25 12:30:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:39
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:41
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:42
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:43
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:44
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:48
# -------------------------------------------
# ('spark', 1)
# ('love', 1)
# ('my', 1)
#
# -------------------------------------------
# Time: 2020-12-25 12:30:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:52
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:53
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:30:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:03
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:31:07
# -------------------------------------------
