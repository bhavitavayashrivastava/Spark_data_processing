# %%
import findspark
findspark.init()
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
import time
from pprint import pprint
sc = SparkContext("local[*]",'WC')
ssc = StreamingContext(sc,1)

# %%
if __name__ == "__main__":
    #sc = SparkContext(appName="PythonStreamingQueueStream")
    #ssc = StreamingContext(sc, 1)
    
    
    rddQueue = []
    for i in range(5):
        rddQueue += [ssc.sparkContext.parallelize([j for j in range(1, 1001)], 10)]
    
    inputStream = ssc.queueStream(rddQueue)
    mappedStream = inputStream.map(lambda x: (x % 10, 1))
    reducedStream = mappedStream.reduceByKey(lambda a, b: a + b)
    reducedStream.pprint()
    
    ssc.start()
    time.sleep(6)
    ssc.stop(stopSparkContext=True, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2020-12-25 12:47:07
# -------------------------------------------
# (4, 100)
# (8, 100)
# (0, 100)
# (1, 100)
# (5, 100)
# (9, 100)
# (2, 100)
# (6, 100)
# (3, 100)
# (7, 100)
#
# -------------------------------------------
# Time: 2020-12-25 12:47:08
# -------------------------------------------
# (4, 100)
# (8, 100)
# (0, 100)
# (1, 100)
# (5, 100)
# (9, 100)
# (2, 100)
# (6, 100)
# (3, 100)
# (7, 100)
#
# -------------------------------------------
# Time: 2020-12-25 12:47:09
# -------------------------------------------
# (4, 100)
# (8, 100)
# (0, 100)
# (1, 100)
# (5, 100)
# (9, 100)
# (2, 100)
# (6, 100)
# (3, 100)
# (7, 100)
#
# -------------------------------------------
# Time: 2020-12-25 12:47:10
# -------------------------------------------
# (4, 100)
# (8, 100)
# (0, 100)
# (1, 100)
# (5, 100)
# (9, 100)
# (2, 100)
# (6, 100)
# (3, 100)
# (7, 100)
#
# -------------------------------------------
# Time: 2020-12-25 12:47:11
# -------------------------------------------
# (4, 100)
# (8, 100)
# (0, 100)
# (1, 100)
# (5, 100)
# (9, 100)
# (2, 100)
# (6, 100)
# (3, 100)
# (7, 100)
#
# -------------------------------------------
# Time: 2020-12-25 12:47:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:47:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:47:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-12-25 12:47:15
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9976df1b08f0> in <module>
#      15     ssc.start()
#      16     time.sleep(6)
# ---> 17     ssc.stop(stopSparkContext=True, stopGraceFully=True)
#
# C:\spark-2.4.4-bin-hadoop2.7\python\pyspark\streaming\context.py in stop(self, stopSparkContext, stopGraceFully)
#     213                               of all received data to be completed
#     214         """
# --> 215         self._jssc.stop(stopSparkContext, stopGraceFully)
#     216         StreamingContext._activeContext = None
#     217         if stopSparkContext:
#
# C:\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# C:\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# C:\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
